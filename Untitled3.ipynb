# %% [markdown]
# <a href="https://colab.research.google.com/github/Ansh-dev-2005/Machine-Learning-and-Artificial-Intelligence/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
car_df = pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/NIIT-Batch/main/auto-mpg.csv")

# %%
car_df.sample
# Out:
# <bound method NDFrame.sample of       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
car_df.drop("car name", axis=1,inplace=True)

# %%
car_df['origin'] = car_df['origin'].replace({1:'america',2:'europe',3:'asia'})

# %%
car_df.sample(10)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 386  25.0          6         181.0        110    2945          16.4
# 329  44.6          4          91.0         67    1850          13.8
# 353  33.0          4         105.0         74    2190          14.2
# 330  40.9          4          85.0          ?    1835          17.3
# 197  29.0          4          90.0         70    1937          14.2
# 29   27.0          4          97.0         88    2130          14.5
# 36   19.0          6         250.0         88    3302          15.5
# 185  26.0          4          98.0         79    2255          17.7
# 336  23.6          4         140.0          ?    2905          14.3
# 106  12.0          8         350.0        180    4499          12.5
#
#      model year   origin
# 386          82  america
# 329          80     asia
# 353          81   europe
# 330          80   europe
# 197          76   europe
# 29           71     asia
# 36           71  america
# ...

# %%
car_df=pd.get_dummies(car_df, columns=['origin'])

# %%
car_df.sample(10)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 237  30.5          4          98.0         63    2051          17.0
# 22   25.0          4         104.0         95    2375          17.5
# 124  11.0          8         350.0        180    3664          11.0
# 348  37.7          4          89.0         62    2050          17.3
# 145  32.0          4          83.0         61    2003          19.0
# 253  20.5          6         200.0         95    3155          18.2
# 294  34.1          4          86.0         65    1975          15.2
# 217  30.0          4         111.0         80    2155          14.8
# 68   13.0          8         350.0        155    4502          13.5
# 109  21.0          4         140.0         72    2401          19.5
#
#      model year  origin_america  origin_asia  origin_europe
# 237          77               1            0              0
# 22           70               0            0              1
# ...

# %%
car_df.isnull().sum()
# Out:
# mpg               0
# cylinders         0
# displacement      0
# horsepower        0
# weight            0
# acceleration      0
# model year        0
# origin_america    0
# origin_asia       0
# origin_europe     0
# dtype: int64

# %%
#@title
car_df.dtypes
# Out:
# mpg               float64
# cylinders           int64
# displacement      float64
# horsepower         object
# weight              int64
# acceleration      float64
# model year          int64
# origin_america      uint8
# origin_asia         uint8
# origin_europe       uint8
# dtype: object

# %%
sns.pairplot(car_df,diag_kind="kde")

# %%
# Split Data

# %% [markdown]
# Split Data

# %%
X=car_df.drop(['mpg'],axis=1)
y=car_df[['mpg']]

# %%
X_train, X_test, y_train, y_text = train_test_split(X, y, test_size=0.30, random_state = 1)

# %% [markdown]
# ## **Fit Linear Model**

# %%
print(X_train)
print(y_train)
# Out:
#      cylinders  displacement horsepower  weight  acceleration  model year  \
# 350          4         105.0         63    2215          14.9          81
# 59           4          97.0         54    2254          23.5          72
# 120          4         121.0        112    2868          15.5          73
# 12           8         400.0        150    3761           9.5          70
# 349          4          91.0         68    1985          16.0          81
# ..         ...           ...        ...     ...           ...         ...
# 393          4         140.0         86    2790          15.6          82
# 255          4         140.0         88    2720          15.4          78
# 72           8         304.0        150    3892          12.5          72
# 235          4          97.0         75    2265          18.2          77
# 37           6         232.0        100    3288          15.5          71
#
#      origin_america  origin_asia  origin_europe
# ...

# %%
car_df.drop("horsepower", axis=1, inplace=True)

print(X_train.dtypes)
print(y_train.dtypes)
# Out:
# cylinders           int64
# displacement      float64
# horsepower         object
# weight              int64
# acceleration      float64
# model year          int64
# origin_america      uint8
# origin_asia         uint8
# origin_europe       uint8
# dtype: object
# mpg    float64
# dtype: object

# %%
if np.issubdtype(X_train.dtypes, np.object_):
    X_train = X_train.astype(float)
if np.issubdtype(y_train.dtypes, np.object_):
    y_train = y_train.astype(float)

# Train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-2f3e95f00b4d> in <module>
#       1 if np.issubdtype(X_train.dtypes, np.object_):
# ----> 2     X_train = X_train.astype(float)
#       3 if np.issubdtype(y_train.dtypes, np.object_):
#       4     y_train = y_train.astype(float)
#       5
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
# ...

# %%
car_df.replace("?", car_df.mean(), inplace=True)

# %%
  if car_df[col].dtype == object:
    print(f"Column {col} contains string data")
  else:
    print(f"Column {col} does not contain string data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-34a1693a2295> in <module>
# ----> 1 if car_df[col].dtype == object:
#       2   print(f"Column {col} contains string data")
#       3 else:
#       4   print(f"Column {col} does not contain string data")
#
# NameError: name 'col' is not defined
